# %% [markdown]
# <a href="https://colab.research.google.com/github/JessicaGreen22/food-sales-location-predictions/blob/main/ReadMe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Sales Predictions**

# %% [markdown]
# Predictions of **Sales** at Different Types of Salesmarkets

# %% [markdown]
# ***Jessica Green***

# %% [markdown]
# **Predict Sales revenue for items at different supermarket types. **

# %% [markdown]
# ## **Data**

# %% [markdown]
# ## **Methods**

# %% [markdown]
# # **Results**

# %%
#correlation to show the most correlation between data 
plt.figure(figsize=(10, 10))
sns.heatmap(corr, cmap= 'coolwarm', annot=True)

# %% [markdown]
# # **Recommendations**

# %% [markdown]
# # **Limitations & Next Steps**

# %% [markdown]
# Additional information and questions, please contact greenmomn_2@yahoo.com
